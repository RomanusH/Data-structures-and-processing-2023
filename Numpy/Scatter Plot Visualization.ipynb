# %%
import matplotlib.pyplot as plt
import numpy as np
import random as rd
x = np.random.randint(0,100,50)
y = np.random.randint(0,100,50)
plt.xlabel('X variable')
plt.ylabel('Y variable')
plt.title('Releation between X and Y')
plt.plot(xpoints, ypoints)
