# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.random.randint(0,150,100)
y = np.random.randint(0,150,100)
plt.xlabel('X variable')
plt.ylabel('Y variable')
plt.title('Releation between X and Y')
plt.scatter(x,y)
