# %%
import matplotlib.pyplot as plt
import numpy as np
x = [2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022]
y = [87761,82761,101629,117561,138027,153965,117366,199383,207913,223271,223068,224111,180625,194842,177869]
plt.bar(x,y, width=0.5)
plt.xlabel('Years')
plt.ylabel('Amount of cars sold per year')
plt.title('Audi Car Sales by U.S. Market in years')
plt.show()
