# %%
import matplotlib.pyplot as plt
import numpy as np
plot = plt.plot(range(50))
plt.xlabel('variable X')
plt.ylabel('variable Y')
plt.title('Releationship between X and Y')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
