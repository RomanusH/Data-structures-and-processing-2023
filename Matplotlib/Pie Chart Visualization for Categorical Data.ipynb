# %%
import matplotlib.pyplot as plt
import numpy as np
x = 'VW', 'Mercedes-Benz', 'BMW', 'Audi', 'Opel', 'Skoda', 'Ford','Others'
y = np.array([18.1,9.0,8.4,8.2,5.7,5.6,5.1,39.9])
plt.pie(y, labels=x)
plt.title("Market Share of Cars on German market in 2011")
plt.show()
